# %%
print("Hello World")
# Out:
# Hello World

# %%
a = 10
b = 20

print("Sum =", a + b)
# Out:
# Sum = 30

# %% [markdown]
# # My First Jupyter Notebook
#
# This notebook is created for Python Exercise 2.+
